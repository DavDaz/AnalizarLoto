# %%
from collections import Counter
from itertools import combinations
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
data = [
    [4, 27, 23, 36, 13, 1],
    [19, 30, 12, 8, 3, 17],
    [35, 28, 4, 20, 1, 25],
    [23, 32, 16, 11, 31, 4],
    [9, 3, 18, 11, 33, 27],
    [19, 3, 36, 5, 28, 18],
    [7, 36, 19, 27, 37, 31],
    [4, 18, 14, 5, 29, 28],
    [8, 33, 9, 36, 23, 1],
    [28, 31, 1, 11, 10, 38],
    [30, 14, 38, 36, 31, 7],
    [33, 18, 29, 12, 7, 10],
    [35, 11, 7, 19, 16, 1],
    [26, 10, 17, 4, 25, 8],
    [28, 7, 5, 2, 33, 3],
    [2, 33, 1, 17, 8, 5],
    [7, 26, 10, 15, 3, 25],
    [7, 6, 5, 1, 21, 19],
    [21, 3, 7, 27, 18, 4],
    [30, 13, 14, 25, 3, 2],
    [29, 17, 25, 19, 27, 2],
    [22, 14, 25, 6, 8, 29],
    [36, 14, 3, 30, 2, 12],
    [8, 16, 20, 21, 6, 27],
    [7, 18, 14, 4, 21, 9],
    [34, 8, 7, 21, 13, 10],
    [2, 32, 36, 34, 10, 20],
    [9, 12, 33, 19, 25, 36],
    [5, 4, 11, 15, 7, 20],
    [16, 37, 13, 29, 32, 2],
    [1, 19, 3, 31, 9, 28],
    [26, 22, 15, 37, 28, 23],
    [35, 14, 29, 27, 26, 30],
    [11, 36, 2, 17, 24, 6],
]

# %%
last_loto = [21, 3, 7, 27, 18, 4]

# %% [markdown]
# ### Metodos

# %%
def contar_coincidencias(array1, array2):
    # Utilizar Counter para contar las ocurrencias de cada número en cada array
    counter1 = Counter(array1)
    counter2 = Counter(array2)

    # Encontrar la intersección de los conjuntos de elementos
    elementos_comunes = list((counter1 & counter2).elements())

    # Contar la cantidad de coincidencias para cada elemento
    cantidad_coincidencias = [min(counter1[num], counter2[num]) for num in elementos_comunes]

    # Crear una lista que contenga cada elemento repetido la cantidad correcta de veces
    coincidencias = [num for num, count in zip(elementos_comunes, cantidad_coincidencias) for _ in range(count)]

    print(f"Hubo coincidencia con {len(coincidencias)} números: {coincidencias}")
    
    # Retornar las coincidencias
    return coincidencias

# %% [markdown]
# ## Analisis Generales de la data

# %% [markdown]
# ### Analizar cantidad de veces que ah jugado un numero

# %%
# Convertir la lista de listas a una lista plana
flat_data = [num for sublist in data for num in sublist]

# Contar la frecuencia de cada número
counter = Counter(flat_data)

# Encontrar los números que más se repiten
most_common_numbers = counter.most_common()

# Calcular el total de elementos en la lista plana
total_elements = len(flat_data)

# Imprimir los resultados con porcentajes
print("Números que más se repiten:")
for num, count in most_common_numbers:
    percentage = (count / total_elements) * 100
    print(f"{num}: {count} veces ({percentage:.2f}%)")
# Out:
# Números que más se repiten:
# 7: 11 veces (5.39%)
# 36: 9 veces (4.41%)
# 3: 9 veces (4.41%)
# 4: 8 veces (3.92%)
# 1: 8 veces (3.92%)
# 19: 8 veces (3.92%)
# 2: 8 veces (3.92%)
# 27: 7 veces (3.43%)
# 8: 7 veces (3.43%)
# 28: 7 veces (3.43%)
# 25: 7 veces (3.43%)
# 14: 7 veces (3.43%)
# 11: 6 veces (2.94%)
# 18: 6 veces (2.94%)
# 33: 6 veces (2.94%)
# 5: 6 veces (2.94%)
# 29: 6 veces (2.94%)
# 10: 6 veces (2.94%)
# 30: 5 veces (2.45%)
# 17: 5 veces (2.45%)
# 31: 5 veces (2.45%)
# 9: 5 veces (2.45%)
# 21: 5 veces (2.45%)
# 23: 4 veces (1.96%)
# 13: 4 veces (1.96%)
# 12: 4 veces (1.96%)
# 20: 4 veces (1.96%)
# 16: 4 veces (1.96%)
# 26: 4 veces (1.96%)
# 6: 4 veces (1.96%)
# 35: 3 veces (1.47%)
# 32: 3 veces (1.47%)
# 37: 3 veces (1.47%)
# 15: 3 veces (1.47%)
# 38: 2 veces (0.98%)
# 22: 2 veces (0.98%)
# 34: 2 veces (0.98%)
# 24: 1 veces (0.49%)

# %% [markdown]
# ### Probabilidad de que aparezca un numero basandonos en todos los numeros que han jugado (juntos)

# %%
# Convertir la lista de listas a una lista plana
flat_data = [num for sublist in data for num in sublist]

# Contar la frecuencia de cada número
counter = Counter(flat_data)

# Calcular el total de elementos en la lista plana
total_elements = len(flat_data)

# Crear un conjunto de números del 1 al 38
all_numbers = set(range(1, 39))

# Calcular la probabilidad de que aparezca cada número
probabilities = {num: (counter[num] / total_elements) for num in all_numbers}

# Imprimir los resultados con probabilidades
print("Probabilidades de que aparezca cada número:")
for num in all_numbers:
    probability = probabilities[num] if num in counter else 0
    print(f"{num}: {probability:.4f}")
# Out:
# Probabilidades de que aparezca cada número:
# 1: 0.0392
# 2: 0.0392
# 3: 0.0441
# 4: 0.0392
# 5: 0.0294
# 6: 0.0196
# 7: 0.0539
# 8: 0.0343
# 9: 0.0245
# 10: 0.0294
# 11: 0.0294
# 12: 0.0196
# 13: 0.0196
# 14: 0.0343
# 15: 0.0147
# 16: 0.0196
# 17: 0.0245
# 18: 0.0294
# 19: 0.0392
# 20: 0.0196
# 21: 0.0245
# 22: 0.0098
# 23: 0.0196
# 24: 0.0049
# 25: 0.0343
# 26: 0.0196
# 27: 0.0343
# 28: 0.0343
# 29: 0.0294
# 30: 0.0245
# 31: 0.0245
# 32: 0.0147
# 33: 0.0294
# 34: 0.0098
# 35: 0.0147
# 36: 0.0441
# 37: 0.0147
# 38: 0.0098

# %% [markdown]
# ### Total de combinaciones posibles para ganar

# %%
# Crear un conjunto de números del 1 al 38
all_numbers = set(range(1, 39))

# Generar todas las combinaciones de 6 números
combinations_6 = list(combinations(all_numbers, 6))

# Contar cuántas combinaciones hay
total_combinations = len(combinations_6)

# Imprimir el resultado
print(f"Total de combinaciones de 6 números del 1 al 38: {total_combinations}")
# Out:
# Total de combinaciones de 6 números del 1 al 38: 2760681

# %% [markdown]
# ### Calcular la probabilidad en porcentaje

# %%
# Calcular la probabilidad en porcentaje
probability_percentage = (1 / total_combinations) * 100

# Imprimir el resultado
print(f"La probabilidad en porcentaje es aproximadamente: {probability_percentage:.6f}%")
# Out:
# La probabilidad en porcentaje es aproximadamente: 0.000036%

# %% [markdown]
# ### Buscar numeros que ya jugaron

# %%
# Crear un conjunto de números del 1 al 38
all_numbers = set(range(1, 39))

# Inicializar una lista para almacenar los números encontrados en cada iteración
found_numbers = []

# Bucle para recorrer cada arreglo
for i, arr in enumerate(data):
    # Agregar los números del arreglo actual a la lista de encontrados
    found_numbers.extend(arr)
    # Obtener el conjunto único de números encontrados hasta el momento
    unique_found_numbers = set(found_numbers)
    # Verificar si se han encontrado todos los números del 1 al 38
    if unique_found_numbers == all_numbers:
        print(f"Todos los números del 1 al 38 fueron encontrados en la iteración {i + 1}")
        break
# Out:
# Todos los números del 1 al 38 fueron encontrados en la iteración 34

# %%
# Conjunto para almacenar los números encontrados
numeros_encontrados = set()

# Variable para llevar el conteo de los bucles
bucle_actual = 0

# Recorrer los datos
for lista_numeros in data:
    bucle_actual += 1
    numeros_encontrados.update(lista_numeros)

    # Verificar si todos los números del 1 al 38 están presentes
    if set(range(1, 39)).issubset(numeros_encontrados):
        print(f"¡Todos los números del 1 al 38 están presentes en el bucle {bucle_actual}!")
        break
else:
    numeros_faltantes = set(range(1, 39)) - numeros_encontrados
    print(f"No se encontraron todos los números del 1 al 38 en los datos proporcionados.")
    print(f"Números encontrados: {numeros_encontrados}")
    print(f"Números faltantes: {numeros_faltantes}")
# Out:
# ¡Todos los números del 1 al 38 están presentes en el bucle 34!

# %% [markdown]
# ## Analisis de Desviacion Estandar

# %% [markdown]
# ### Calcular la desviación estándar para cada conjunto

# %%
# Calcular la desviación estándar para cada conjunto
desviaciones_estandar = [np.std(sublista) for sublista in data]

# Imprimir resultados
for i, desviacion in enumerate(desviaciones_estandar, start=1):
    desviacion_redondeada = round(desviacion, 2)
    print(f"Bucle {i}: Desviación estándar = {desviacion:.2f}")
    # Almacenar en la lista después de imprimir
    desviaciones_estandar[i-1] = desviacion_redondeada
# Out:
# Bucle 1: Desviación estándar = 12.50
# Bucle 2: Desviación estándar = 8.63
# Bucle 3: Desviación estándar = 12.40
# Bucle 4: Desviación estándar = 10.21
# Bucle 5: Desviación estándar = 10.43
# Bucle 6: Desviación estándar = 11.68
# Bucle 7: Desviación estándar = 10.46
# Bucle 8: Desviación estándar = 9.88
# Bucle 9: Desviación estándar = 13.19
# Bucle 10: Desviación estándar = 13.23
# Bucle 11: Desviación estándar = 11.47
# Bucle 12: Desviación estándar = 9.72
# Bucle 13: Desviación estándar = 10.75
# Bucle 14: Desviación estándar = 8.37
# Bucle 15: Desviación estándar = 12.56
# Bucle 16: Desviación estándar = 11.15
# Bucle 17: Desviación estándar = 8.67
# Bucle 18: Desviación estándar = 7.45
# Bucle 19: Desviación estándar = 9.14
# Bucle 20: Desviación estándar = 10.34
# Bucle 21: Desviación estándar = 9.03
# Bucle 22: Desviación estándar = 8.60
# Bucle 23: Desviación estándar = 12.79
# Bucle 24: Desviación estándar = 7.36
# Bucle 25: Desviación estándar = 6.04
# Bucle 26: Desviación estándar = 9.46
# Bucle 27: Desviación estándar = 12.83
# Bucle 28: Desviación estándar = 10.03
# Bucle 29: Desviación estándar = 5.71
# Bucle 30: Desviación estándar = 12.18
# Bucle 31: Desviación estándar = 11.67
# Bucle 32: Desviación estándar = 6.67
# Bucle 33: Desviación estándar = 6.41
# Bucle 34: Desviación estándar = 11.45

# %% [markdown]
# ### Promedio de la desviacion estandar

# %%
# IMPORTANTE  Necesitas la desviacion anterior para ejecutar este codigo
# Calcular el promedio de las desviaciones estándar
promedio_desviaciones = sum(desviaciones_estandar) / len(desviaciones_estandar)

# Imprimir el resultado
print(f"El promedio de las desviaciones estándar es: {promedio_desviaciones:.2f}")
# Out:
# El promedio de las desviaciones estándar es: 10.07

# %% [markdown]
# ### Grafica de desviacion Estandar por sorteo

# %%
# Desviaciones estándar proporcionadas
# Índices para los bucles
bucles = list(range(1, len(desviaciones_estandar) + 1))

# Crear el gráfico de barras
plt.bar(bucles, desviaciones_estandar, color='blue')
plt.xlabel('Bucle')
plt.ylabel('Desviación estándar')
plt.title('Desviación estándar en cada bucle')
plt.grid(axis='y')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Generador de numeros utilizando desviacion

# %%
# Probabilidades proporcionadas
probabilidades = probabilities

# Número de conjuntos a generar
num_conjuntos = 1000

# Lista para almacenar los conjuntos generados
conjuntos_generados = []

# Generar conjuntos basados en las probabilidades
for _ in range(num_conjuntos):
    # Ordenar las claves por ponderación de mayor a menor
    claves_ordenadas = sorted(probabilidades, key=probabilidades.get, reverse=True)
    
    # Seleccionar 6 elementos sin reemplazo
    conjunto = random.sample(claves_ordenadas, k=6)
    
    # Agregar el conjunto a la lista
    conjuntos_generados.append(conjunto)

# Calcular la desviación estándar de cada conjunto
desviaciones_estandar_generadas = [np.std(conjunto) for conjunto in conjuntos_generados]

# Convertir la lista a un array de NumPy antes de realizar la resta
desviaciones_estandar_generadas = np.array(desviaciones_estandar_generadas)

# Encontrar el conjunto con desviación estándar más cercana a la observada
indice_min_desviacion = np.argmin(np.abs(desviaciones_estandar_generadas - 9.15))
conjunto_seleccionado = conjuntos_generados[indice_min_desviacion]

# Imprimir resultados
print("Conjunto seleccionado:", conjunto_seleccionado)
print("Desviación estándar del conjunto seleccionado:", desviaciones_estandar_generadas[indice_min_desviacion])
# Out:
# Conjunto seleccionado: [5, 3, 24, 28, 15, 18]
# Desviación estándar del conjunto seleccionado: 9.142392101268317

# %%
contar_coincidencias(conjunto_seleccionado, last_loto)
# Out:
# Hubo coincidencia con 2 números: [3, 18]
# [3, 18]

# %% [markdown]
# # Simuladores de Loto

# %% [markdown]
# ## Simulador Generico (Version sin revizar)

# %%
def generar_conjuntos(probabilidades, num_conjuntos):
    conjuntos_generados = []

    for _ in range(num_conjuntos):
        conjunto = random.choices(list(probabilidades.keys()), weights=list(probabilidades.values()), k=6)
        conjuntos_generados.append(conjunto)

    return conjuntos_generados

def encontrar_conjunto_deseado(probabilidades, last_loto):
    conjuntos_generados = []
    iteracion = 0

    while True:
        conjunto = random.choices(list(probabilidades.keys()), weights=list(probabilidades.values()), k=6)
        conjuntos_generados.append(conjunto)

        desviacion_estandar_generada = np.std(conjunto)

        if set(conjunto) == set(last_loto):
            print(f"Se encontró una coincidencia en la iteración {iteracion + 1}")
            break

        if iteracion % 100 == 0:
            print(f"Iteración {iteracion + 1}: Desviación estándar = {desviacion_estandar_generada}")

        iteracion += 1

    conjunto_seleccionado = conjuntos_generados[-1]

    print("Conjunto seleccionado:", conjunto_seleccionado)
    print("Desviación estándar del conjunto seleccionado:", desviacion_estandar_generada)
    contar_coincidencias(conjunto_seleccionado, last_loto)


# Encontrar conjunto deseado
encontrar_conjunto_deseado(probabilidades, last_loto)
# Out:
# Iteración 1: Desviación estándar = 8.098353742170895
# Iteración 101: Desviación estándar = 6.994045086119096
# Iteración 201: Desviación estándar = 9.878427675158296
# Iteración 301: Desviación estándar = 12.433154601038842
# Iteración 401: Desviación estándar = 10.434983894999018
# Iteración 501: Desviación estándar = 6.082762530298219
# Iteración 601: Desviación estándar = 7.945998294040145
# Iteración 701: Desviación estándar = 9.044642367476756
# Iteración 801: Desviación estándar = 8.900686615212459
# Iteración 901: Desviación estándar = 12.6414222125343
# Iteración 1001: Desviación estándar = 9.291573243177568
# Iteración 1101: Desviación estándar = 10.843584893075414
# Iteración 1201: Desviación estándar = 9.007712744581108
# Iteración 1301: Desviación estándar = 6.0461190490723515
# Iteración 1401: Desviación estándar = 8.976822006330154
# Iteración 1501: Desviación estándar = 10.192589900947103
# Iteración 1601: Desviación estándar = 10.688779163215974
# Iteración 1701: Desviación estándar = 9.081421817216851
# Iteración 1801: Desviación estándar = 13.399834161494521
# Iteración 1901: Desviación estándar = 6.757711644237764
# Iteración 2001: Desviación estándar = 11.427306477614632
# Iteración 2101: Desviación estándar = 10.225241100118645
# Iteración 2201: Desviación estándar = 9.906507401142386
# Iteración 2301: Desviación estándar = 12.84198842339716
# Iteración 2401: Desviación estándar = 9.374907406950156
# Iteración 2501: Desviación estándar = 6.465721580423608
# Iteración 2601: Desviación estándar = 12.378296418418095
# Iteración 2701: Desviación estándar = 6.60807586719967
# Iteración 2801: Desviación estándar = 11.08552609887726
# Iteración 2901: Desviación estándar = 10.6366765904059
# Iteración 3001: Desviación estándar = 9.72396809720988
# Iteración 3101: Desviación estándar = 8.914719413544221
# Iteración 3201: Desviación estándar = 3.5433819375782165
# Iteración 3301: Desviación estándar = 11.557825631723873
# Iteración 3401: Desviación estándar = 9.044642367476756
# Iteración 3501: Desviación estándar = 10.903618155864084
# Iteración 3601: Desviación estándar = 7.937253933193772
# Iteración 3701: Desviación estándar = 9.081421817216851
# Iteración 3801: Desviación estándar = 11.908213785264168
# Iteración 3901: Desviación estándar = 12.727922061357855
# Iteración 4001: Desviación estándar = 7.249521056977183
# Iteración 4101: Desviación estándar = 11.742609969205693
# Iteración 4201: Desviación estándar = 10.188501143718616
# Iteración 4301: Desviación estándar = 7.602996485304695
# Iteración 4401: Desviación estándar = 14.004959439030479
# Iteración 4501: Desviación estándar = 11.090536506409418
# Iteración 4601: Desviación estándar = 10.960788698304922
# Iteración 4701: Desviación estándar = 11.308796969124916
# Iteración 4801: Desviación estándar = 10.43498389499902
# Iteración 4901: Desviación estándar = 13.428824718989125
# Iteración 5001: Desviación estándar = 8.32165848854662
# Iteración 5101: Desviación estándar = 8.763877883423271
# Iteración 5201: Desviación estándar = 7.888106377466155
# Iteración 5301: Desviación estándar = 7.033649282003064
# Iteración 5401: Desviación estándar = 9.334821309960299
# Iteración 5501: Desviación estándar = 10.9188929027728
# Iteración 5601: Desviación estándar = 9.775252199076787
# Iteración 5701: Desviación estándar = 10.640593133008245
# Iteración 5801: Desviación estándar = 11.275588183721899
# Iteración 5901: Desviación estándar = 8.439325934114775
# Iteración 6001: Desviación estándar = 10.177589760514683
# Iteración 6101: Desviación estándar = 7.5203427817856525
# Iteración 6201: Desviación estándar = 8.64902049688608
# Iteración 6301: Desviación estándar = 8.266397845091497
# Iteración 6401: Desviación estándar = 9.826268648655784
# Iteración 6501: Desviación estándar = 11.5
# Iteración 6601: Desviación estándar = 12.966838045139951
# Iteración 6701: Desviación estándar = 11.991895411299899
# Iteración 6801: Desviación estándar = 11.16542281629615
# Iteración 6901: Desviación estándar = 8.858454843945541
# Iteración 7001: Desviación estándar = 11.180339887498949
# Iteración 7101: Desviación estándar = 12.631530214330944
# Iteración 7201: Desviación estándar = 11.87083260208258
# Iteración 7301: Desviación estándar = 6.6687496745808525
# Iteración 7401: Desviación estándar = 12.239507978491439
# Iteración 7501: Desviación estándar = 7.243771270700243
# Iteración 7601: Desviación estándar = 11.100550536897808
# Iteración 7701: Desviación estándar = 7.234178138070235
# Iteración 7801: Desviación estándar = 10.263202878893768
# Iteración 7901: Desviación estándar = 10.699169230469355
# Iteración 8001: Desviación estándar = 12.1335164821342
# Iteración 8101: Desviación estándar = 12.762793146051099
# Iteración 8201: Desviación estándar = 8.958236433584458
# Iteración 8301: Desviación estándar = 13.981138087517131
# Iteración 8401: Desviación estándar = 6.683312551921141
# Iteración 8501: Desviación estándar = 8.801830617673929
# Iteración 8601: Desviación estándar = 13.446395634353303
# Iteración 8701: Desviación estándar = 7.492588930996341
# Iteración 8801: Desviación estándar = 12.405196043952264
# Iteración 8901: Desviación estándar = 13.085190950927014
# Iteración 9001: Desviación estándar = 8.787617550976046
# Iteración 9101: Desviación estándar = 12.34796429466097
# Iteración 9201: Desviación estándar = 15.220600075774499
# Iteración 9301: Desviación estándar = 9.822027398771713
# Iteración 9401: Desviación estándar = 9.476579317219667
# Iteración 9501: Desviación estándar = 8.076027626390479
# Iteración 9601: Desviación estándar = 4.6696419087073
# Iteración 9701: Desviación estándar = 9.363047936792093
# Iteración 9801: Desviación estándar = 11.785113019775793
# Iteración 9901: Desviación estándar = 3.8477987935383986
# Iteración 10001: Desviación estándar = 6.110100926607787
# Iteración 10101: Desviación estándar = 7.559026980299044
# Iteración 10201: Desviación estándar = 9.860132971832694
# Iteración 10301: Desviación estándar = 7.425556469981821
# Iteración 10401: Desviación estándar = 11.939663125714878
# Iteración 10501: Desviación estándar = 10.542243067245645
# Iteración 10601: Desviación estándar = 9.118052911059953
# Iteración 10701: Desviación estándar = 8.99536917900909
# Iteración 10801: Desviación estándar = 8.993825042154693
# Iteración 10901: Desviación estándar = 7.632168761236874
# Iteración 11001: Desviación estándar = 9.049247973665484
# Iteración 11101: Desviación estándar = 11.556623882239812
# Iteración 11201: Desviación estándar = 11.86029791643813
# Iteración 11301: Desviación estándar = 8.219218670625303
# Iteración 11401: Desviación estándar = 3.872983346207417
# Iteración 11501: Desviación estándar = 9.637888196533973
# Iteración 11601: Desviación estándar = 6.324555320336759
# Iteración 11701: Desviación estándar = 10.3400515794974
# Iteración 11801: Desviación estándar = 11.407843305765068
# Iteración 11901: Desviación estándar = 14.580237766694113
# Iteración 12001: Desviación estándar = 12.257650672131263
# Iteración 12101: Desviación estándar = 11.220021786471223
# Iteración 12201: Desviación estándar = 12.552113589175153
# Iteración 12301: Desviación estándar = 3.4840908267278126
# Iteración 12401: Desviación estándar = 9.251126057585278
# Iteración 12501: Desviación estándar = 9.299044156375547
# Iteración 12601: Desviación estándar = 5.734883511361751
# Iteración 12701: Desviación estándar = 13.695092389449425
# Iteración 12801: Desviación estándar = 8.220908303425682
# Iteración 12901: Desviación estándar = 10.456258094238748
# Iteración 13001: Desviación estándar = 10.430990152212567
# Iteración 13101: Desviación estándar = 10.53169818531972
# Iteración 13201: Desviación estándar = 13.263358046387298
# Iteración 13301: Desviación estándar = 7.088723439378913
# Iteración 13401: Desviación estándar = 10.63014581273465
# Iteración 13501: Desviación estándar = 8.65544144839919
# Iteración 13601: Desviación estándar = 11.31984491452462
# Iteración 13701: Desviación estándar = 9.208993189027536
# Iteración 13801: Desviación estándar = 8.214147686901072
# Iteración 13901: Desviación estándar = 8.89600409672168
# Iteración 14001: Desviación estándar = 8.465616732800196
# Iteración 14101: Desviación estándar = 13.6106575888162
# Iteración 14201: Desviación estándar = 9.533566430716727
# Iteración 14301: Desviación estándar = 14.873541011548737
# Iteración 14401: Desviación estándar = 11.339459128782702
# Iteración 14501: Desviación estándar = 7.365459931328117
# Iteración 14601: Desviación estándar = 10.949378470437894
# Iteración 14701: Desviación estándar = 4.43471156521669
# Iteración 14801: Desviación estándar = 5.405758246742285
# Iteración 14901: Desviación estándar = 13.446395634353301
# Iteración 15001: Desviación estándar = 7.009913614937696
# Iteración 15101: Desviación estándar = 8.981462390204987
# Iteración 15201: Desviación estándar = 9.299044156375547
# Iteración 15301: Desviación estándar = 13.634107557478375
# Iteración 15401: Desviación estándar = 14.918296000400165
# Iteración 15501: Desviación estándar = 6.551081335677848
# Iteración 15601: Desviación estándar = 11.852097798374018
# Iteración 15701: Desviación estándar = 12.0
# Iteración 15801: Desviación estándar = 9.007712744581106
# Iteración 15901: Desviación estándar = 12.110601416389967
# Iteración 16001: Desviación estándar = 12.535505130982513
# Iteración 16101: Desviación estándar = 12.622730819174325
# Iteración 16201: Desviación estándar = 14.197026292697903
# Iteración 16301: Desviación estándar = 8.524474568362947
# Iteración 16401: Desviación estándar = 8.158158833680279
# Iteración 16501: Desviación estándar = 6.238322424070967
# Iteración 16601: Desviación estándar = 11.4564392373896
# Iteración 16701: Desviación estándar = 8.493461537493939
# Iteración 16801: Desviación estándar = 11.6963907063485
# Iteración 16901: Desviación estándar = 12.736648783028533
# Iteración 17001: Desviación estándar = 5.374838498865699
# Iteración 17101: Desviación estándar = 7.593857166596345
# Iteración 17201: Desviación estándar = 11.869662543176569
# Iteración 17301: Desviación estándar = 10.734161458736413
# Iteración 17401: Desviación estándar = 12.079597123524719
# Iteración 17501: Desviación estándar = 13.708270009985457
# Iteración 17601: Desviación estándar = 9.46337971105226
# Iteración 17701: Desviación estándar = 13.07244770075172
# Iteración 17801: Desviación estándar = 4.988876515698588
# Iteración 17901: Desviación estándar = 13.097921802925667
# Iteración 18001: Desviación estándar = 11.06671686735602
# Iteración 18101: Desviación estándar = 10.382945418115012
# Iteración 18201: Desviación estándar = 13.483529046787252
# Iteración 18301: Desviación estándar = 7.371114795831994
# Iteración 18401: Desviación estándar = 9.882644720249063
# Iteración 18501: Desviación estándar = 9.215023964519391
# Iteración 18601: Desviación estándar = 10.939226054281294
# Iteración 18701: Desviación estándar = 9.945685831890462
# Iteración 18801: Desviación estándar = 7.536946036396675
# Iteración 18901: Desviación estándar = 10.418999738725189
# Iteración 19001: Desviación estándar = 9.190877119308158
# Iteración 19101: Desviación estándar = 7.505553499465135
# Iteración 19201: Desviación estándar = 10.372238588334406
# Iteración 19301: Desviación estándar = 8.591015979239915
# Iteración 19401: Desviación estándar = 11.567435132973754
# Iteración 19501: Desviación estándar = 11.294049564064943
# Iteración 19601: Desviación estándar = 9.882644720249063
# Iteración 19701: Desviación estándar = 5.408326913195984
# Iteración 19801: Desviación estándar = 9.568466729604882
# Iteración 19901: Desviación estándar = 12.565384549980509
# Iteración 20001: Desviación estándar = 11.88369564665059
# Iteración 20101: Desviación estándar = 10.25372561018135
# Iteración 20201: Desviación estándar = 9.476579317219667
# Iteración 20301: Desviación estándar = 8.925618559330589
# Iteración 20401: Desviación estándar = 6.7679801680823175
# Iteración 20501: Desviación estándar = 7.438637868140466
# Iteración 20601: Desviación estándar = 5.07991688470939
# Iteración 20701: Desviación estándar = 7.340905181848413
# Iteración 20801: Desviación estándar = 10.208928554075703
# Iteración 20901: Desviación estándar = 10.302372973683726
# Iteración 21001: Desviación estándar = 10.366881026722657
# Iteración 21101: Desviación estándar = 11.832159566199232
# Iteración 21201: Desviación estándar = 5.842849380986035
# Iteración 21301: Desviación estándar = 7.234178138070235
# Iteración 21401: Desviación estándar = 11.220021786471223
# Iteración 21501: Desviación estándar = 7.646713164636308
# Iteración 21601: Desviación estándar = 9.7082439194738
# Iteración 21701: Desviación estándar = 11.116804097101529
# Iteración 21801: Desviación estándar = 12.840906856172147
# Iteración 21901: Desviación estándar = 12.879786057574439
# Iteración 22001: Desviación estándar = 11.912878185672287
# Iteración 22101: Desviación estándar = 6.896053621859068
# Iteración 22201: Desviación estándar = 9.498537899183338
# Iteración 22301: Desviación estándar = 5.7638721552635275
# Iteración 22401: Desviación estándar = 6.568020165079344
# Iteración 22501: Desviación estándar = 10.579067381705567
# Iteración 22601: Desviación estándar = 11.610579466829188
# Iteración 22701: Desviación estándar = 7.781745019952501
# Iteración 22801: Desviación estándar = 10.354816378006046
# Iteración 22901: Desviación estándar = 7.243771270700244
# Iteración 23001: Desviación estándar = 6.79869268479038
# Iteración 23101: Desviación estándar = 11.294049564064943
# Iteración 23201: Desviación estándar = 7.861650943380503
# Iteración 23301: Desviación estándar = 11.880188924797825
# Iteración 23401: Desviación estándar = 8.205689083394114
# Iteración 23501: Desviación estándar = 7.874007874011811
# Iteración 23601: Desviación estándar = 6.454972243679028
# Iteración 23701: Desviación estándar = 5.3359368645273735
# Iteración 23801: Desviación estándar = 11.036555420762202
# Iteración 23901: Desviación estándar = 10.939226054281294
# Iteración 24001: Desviación estándar = 9.912113800799505
# Iteración 24101: Desviación estándar = 6.465721580423608
# Iteración 24201: Desviación estándar = 12.463279397226612
# Iteración 24301: Desviación estándar = 7.972173828734265
# Iteración 24401: Desviación estándar = 12.074997124453304
# Iteración 24501: Desviación estándar = 9.906507401142388
# Iteración 24601: Desviación estándar = 9.172725270544674
# Iteración 24701: Desviación estándar = 9.827681991870378
# Iteración 24801: Desviación estándar = 12.548793656054045
# Iteración 24901: Desviación estándar = 11.908213785264167
# Iteración 25001: Desviación estándar = 11.036555420762202
# Iteración 25101: Desviación estándar = 12.0381338531629
# Iteración 25201: Desviación estándar = 12.945398152754258
# Iteración 25301: Desviación estándar = 13.613718571108091
# Iteración 25401: Desviación estándar = 13.056501147789259
# Iteración 25501: Desviación estándar = 11.239810200058244
# Iteración 25601: Desviación estándar = 8.80814017448254
# Iteración 25701: Desviación estándar = 11.31984491452462
# Iteración 25801: Desviación estándar = 12.065791865158845
# Iteración 25901: Desviación estándar = 8.517954892787092
# Iteración 26001: Desviación estándar = 9.539392014169456
# Iteración 26101: Desviación estándar = 11.742609969205692
# Iteración 26201: Desviación estándar = 8.858454843945541
# Iteración 26301: Desviación estándar = 10.765170174636761
# Iteración 26401: Desviación estándar = 8.952032667997189
# Iteración 26501: Desviación estándar = 12.889487533990204
# Iteración 26601: Desviación estándar = 8.920949127381757
# Iteración 26701: Desviación estándar = 14.761059883656353
# Iteración 26801: Desviación estándar = 12.188336865854815
# Iteración 26901: Desviación estándar = 6.718548123582124
# Iteración 27001: Desviación estándar = 15.31248582765784
# Iteración 27101: Desviación estándar = 10.21028892833107
# Iteración 27201: Desviación estándar = 4.346134936801766
# Iteración 27301: Desviación estándar = 10.949378470437894
# Iteración 27401: Desviación estándar = 12.485547200218695
# Iteración 27501: Desviación estándar = 13.461880337539116
# Iteración 27601: Desviación estándar = 13.158225142050462
# Iteración 27701: Desviación estándar = 4.425306015783918
# Iteración 27801: Desviación estándar = 12.280291346525763
# Iteración 27901: Desviación estándar = 9.321420969406374
# Iteración 28001: Desviación estándar = 11.553017883748915
# Iteración 28101: Desviación estándar = 7.754926749421228
# Iteración 28201: Desviación estándar = 9.585869229698938
# Iteración 28301: Desviación estándar = 6.896053621859067
# Iteración 28401: Desviación estándar = 9.673847907287634
# Iteración 28501: Desviación estándar = 11.32352516764202
# Iteración 28601: Desviación estándar = 10.073342157507716
# Iteración 28701: Desviación estándar = 12.151817422372122
# Iteración 28801: Desviación estándar = 12.95826634495011
# Iteración 28901: Desviación estándar = 9.72539630726344
# Iteración 29001: Desviación estándar = 7.4703116103383245
# Iteración 29101: Desviación estándar = 13.42158295019216
# Iteración 29201: Desviación estándar = 8.386497083606082
# Iteración 29301: Desviación estándar = 13.682917167849194
# Iteración 29401: Desviación estándar = 13.495884146245807
# Iteración 29501: Desviación estándar = 11.245986938558225
# Iteración 29601: Desviación estándar = 10.888321980707385
# Iteración 29701: Desviación estándar = 12.707172078091263
# Iteración 29801: Desviación estándar = 11.897712198383164
# Iteración 29901: Desviación estándar = 10.969655114602888
# Iteración 30001: Desviación estándar = 6.962199524735141
# Iteración 30101: Desviación estándar = 13.888444437333106
# Iteración 30201: Desviación estándar = 9.763879010584539
# Iteración 30301: Desviación estándar = 9.702519718551923
# Iteración 30401: Desviación estándar = 10.386957633921922
# Iteración 30501: Desviación estándar = 6.841458583924597
# Iteración 30601: Desviación estándar = 9.018499505645789
# Iteración 30701: Desviación estándar = 6.0941684329274075
# Iteración 30801: Desviación estándar = 11.460075625114056
# Iteración 30901: Desviación estándar = 11.14550233153366
# Iteración 31001: Desviación estándar = 9.809292646374775
# Iteración 31101: Desviación estándar = 9.067647005823629
# Iteración 31201: Desviación estándar = 10.807661891248983
# Iteración 31301: Desviación estándar = 11.753250141509321
# Iteración 31401: Desviación estándar = 9.231588282750819
# Iteración 31501: Desviación estándar = 10.41499986664533
# Iteración 31601: Desviación estándar = 9.322910847297997
# Iteración 31701: Desviación estándar = 5.639641438562877
# Iteración 31801: Desviación estándar = 8.029459646963938
# Iteración 31901: Desviación estándar = 10.853826770109956
# Iteración 32001: Desviación estándar = 8.339997335464536
# Iteración 32101: Desviación estándar = 8.25462833135986
# Iteración 32201: Desviación estándar = 7.571877794400365
# Iteración 32301: Desviación estándar = 11.466133708544577
# Iteración 32401: Desviación estándar = 10.934146311237816
# Iteración 32501: Desviación estándar = 11.313708498984761
# Iteración 32601: Desviación estándar = 10.703062905334884
# Iteración 32701: Desviación estándar = 10.86917149045358
# Iteración 32801: Desviación estándar = 9.215023964519391
# Iteración 32901: Desviación estándar = 11.38346754435279
# Iteración 33001: Desviación estándar = 5.507570547286102
# Iteración 33101: Desviación estándar = 10.6092203085597
# Iteración 33201: Desviación estándar = 11.290359702959964
# Iteración 33301: Desviación estándar = 9.237604307034012
# Iteración 33401: Desviación estándar = 12.802994441405755
# Iteración 33501: Desviación estándar = 6.7494855771055295
# Iteración 33601: Desviación estándar = 12.707172078091263
# Iteración 33701: Desviación estándar = 10.6366765904059
# Iteración 33801: Desviación estándar = 10.040196987886022
# Iteración 33901: Desviación estándar = 7.197607627229727
# Iteración 34001: Desviación estándar = 10.15983376941878
# Iteración 34101: Desviación estándar = 6.643710475998249
# Iteración 34201: Desviación estándar = 10.242883708539635
# Iteración 34301: Desviación estándar = 13.186693629901656
# Iteración 34401: Desviación estándar = 9.809292646374775
# Iteración 34501: Desviación estándar = 10.311805532172013
# Iteración 34601: Desviación estándar = 4.9805175991613115
# Iteración 34701: Desviación estándar = 12.644717825593773
# Iteración 34801: Desviación estándar = 11.141763275572178
# Iteración 34901: Desviación estándar = 6.551081335677848
# Iteración 35001: Desviación estándar = 11.718930554164631
# Iteración 35101: Desviación estándar = 12.253117517141868
# Iteración 35201: Desviación estándar = 5.405758246742285
# Iteración 35301: Desviación estándar = 10.624918300339484
# Iteración 35401: Desviación estándar = 14.205828224906691
# Iteración 35501: Desviación estándar = 12.876550607812465
# Iteración 35601: Desviación estándar = 5.580223014261069
# Iteración 35701: Desviación estándar = 11.305111921407748
# Iteración 35801: Desviación estándar = 13.120171069345433
# Iteración 35901: Desviación estándar = 6.5
# Iteración 36001: Desviación estándar = 7.039570693980959
# Iteración 36101: Desviación estándar = 12.982894729433632
# Iteración 36201: Desviación estándar = 9.267625849638561
# Iteración 36301: Desviación estándar = 8.234412884690418
# Iteración 36401: Desviación estándar = 3.496029493900505
# Iteración 36501: Desviación estándar = 10.826921179274477
# Iteración 36601: Desviación estándar = 12.854960132182441
# Iteración 36701: Desviación estándar = 5.32290647422377
# Iteración 36801: Desviación estándar = 12.736648783028533
# Iteración 36901: Desviación estándar = 9.882644720249063
# Iteración 37001: Desviación estándar = 11.115554667022044
# Iteración 37101: Desviación estándar = 12.512216252748974
# Iteración 37201: Desviación estándar = 11.279282877125754
# Iteración 37301: Desviación estándar = 11.186549463033224
# Iteración 37401: Desviación estándar = 6.394442031083626
# Iteración 37501: Desviación estándar = 7.357913351548039
# Iteración 37601: Desviación estándar = 7.564537145273478
# Iteración 37701: Desviación estándar = 2.9297326385411577
# Iteración 37801: Desviación estándar = 7.243771270700243
# Iteración 37901: Desviación estándar = 9.249624617007738
# Iteración 38001: Desviación estándar = 9.321420969406375
# Iteración 38101: Desviación estándar = 11.922201511838697
# Iteración 38201: Desviación estándar = 10.558040643141236
# Iteración 38301: Desviación estándar = 10.062305898749054
# Iteración 38401: Desviación estándar = 11.216307572260826
# Iteración 38501: Desviación estándar = 8.070866675202167
# Iteración 38601: Desviación estándar = 10.765170174636761
# Iteración 38701: Desviación estándar = 9.973576200251452
# Iteración 38801: Desviación estándar = 13.287420951996499
# Iteración 38901: Desviación estándar = 10.5
# Iteración 39001: Desviación estándar = 13.03094607292792
# Iteración 39101: Desviación estándar = 7.7190241179396075
# Iteración 39201: Desviación estándar = 8.744839748229936
# Iteración 39301: Desviación estándar = 6.209312003399052
# Iteración 39401: Desviación estándar = 9.51752769017949
# Iteración 39501: Desviación estándar = 6.99205898780101
# Iteración 39601: Desviación estándar = 12.189476335484365
# Iteración 39701: Desviación estándar = 12.288205727444508
# Iteración 39801: Desviación estándar = 9.706813185707357
# Iteración 39901: Desviación estándar = 10.699169230469355
# Iteración 40001: Desviación estándar = 11.426091000668407
# Iteración 40101: Desviación estándar = 11.030261405182864
# Iteración 40201: Desviación estándar = 8.406346808612328
# Iteración 40301: Desviación estándar = 10.749676997731399
# Iteración 40401: Desviación estándar = 9.633564011078949
# Iteración 40501: Desviación estándar = 11.653564070942227
# Iteración 40601: Desviación estándar = 11.524129275375019
# Iteración 40701: Desviación estándar = 7.646713164636308
# Iteración 40801: Desviación estándar = 9.388231403671774
# Iteración 40901: Desviación estándar = 9.620579793107874
# Iteración 41001: Desviación estándar = 8.426149773176359
# Iteración 41101: Desviación estándar = 11.513277359447029
# Iteración 41201: Desviación estándar = 5.315072906367325
# Iteración 41301: Desviación estándar = 5.033222956847166
# Iteración 41401: Desviación estándar = 10.208928554075703
# Iteración 41501: Desviación estándar = 5.489889697333535
# Iteración 41601: Desviación estándar = 7.952986860293433
# Iteración 41701: Desviación estándar = 9.860132971832693
# Iteración 41801: Desviación estándar = 4.203173404306164
# Iteración 41901: Desviación estándar = 11.216307572260828
# Iteración 42001: Desviación estándar = 9.533566430716728
# Iteración 42101: Desviación estándar = 5.617433182117573
# Iteración 42201: Desviación estándar = 15.323366325829175
# Iteración 42301: Desviación estándar = 12.893796958227627
# Iteración 42401: Desviación estándar = 6.724747000610672
# Iteración 42501: Desviación estándar = 8.858454843945541
# Iteración 42601: Desviación estándar = 11.739061101960223
# Iteración 42701: Desviación estándar = 9.303523824635242
# Iteración 42801: Desviación estándar = 12.418624006798105
# Iteración 42901: Desviación estándar = 8.341662504161466
# Iteración 43001: Desviación estándar = 11.7011395456454
# Iteración 43101: Desviación estándar = 12.525529485370624
# Iteración 43201: Desviación estándar = 4.890466917040404
# Iteración 43301: Desviación estándar = 8.827041784576908
# Iteración 43401: Desviación estándar = 8.64902049688608
# Iteración 43501: Desviación estándar = 13.461880337539114
# Iteración 43601: Desviación estándar = 8.933395522171597
# Iteración 43701: Desviación estándar = 12.26104943849968
# Iteración 43801: Desviación estándar = 9.177266598624136
# Iteración 43901: Desviación estándar = 8.286535263104035
# Iteración 44001: Desviación estándar = 12.157530816557923
# Iteración 44101: Desviación estándar = 10.089873911776873
# Iteración 44201: Desviación estándar = 6.531972647421808
# Iteración 44301: Desviación estándar = 8.029459646963938
# Iteración 44401: Desviación estándar = 9.334821309960299
# Iteración 44501: Desviación estándar = 9.118052911059953
# Iteración 44601: Desviación estándar = 11.451588924201257
# Iteración 44701: Desviación estándar = 10.418999738725189
# Iteración 44801: Desviación estándar = 7.888106377466155
# Iteración 44901: Desviación estándar = 9.844626283748239
# Iteración 45001: Desviación estándar = 12.202003478482085
# Iteración 45101: Desviación estándar = 6.683312551921141
# Iteración 45201: Desviación estándar = 11.696390706348499
# Iteración 45301: Desviación estándar = 6.69991708074726
# Iteración 45401: Desviación estándar = 5.814254514170803
# Iteración 45501: Desviación estándar = 12.672147936846908
# Iteración 45601: Desviación estándar = 11.795714852813663
# Iteración 45701: Desviación estándar = 5.727613425813193
# Iteración 45801: Desviación estándar = 13.0
# Iteración 45901: Desviación estándar = 9.533566430716727
# Iteración 46001: Desviación estándar = 10.176225014982498
# Iteración 46101: Desviación estándar = 9.72967967955095
# Iteración 46201: Desviación estándar = 14.557357818871756
# Iteración 46301: Desviación estándar = 9.872802146413257
# Iteración 46401: Desviación estándar = 12.092238098144701
# Iteración 46501: Desviación estándar = 13.650396819628847
# Iteración 46601: Desviación estándar = 11.86966254317657
# Iteración 46701: Desviación estándar = 13.085190950927014
# Iteración 46801: Desviación estándar = 10.482790129010926
# Iteración 46901: Desviación estándar = 11.2644968324772
# Iteración 47001: Desviación estándar = 12.95826634495011
# Iteración 47101: Desviación estándar = 7.32006375199925
# Iteración 47201: Desviación estándar = 11.393224107141734
# Iteración 47301: Desviación estándar = 7.602996485304695
# Iteración 47401: Desviación estándar = 14.071247279470288
# Iteración 47501: Desviación estándar = 8.975274678557506
# Iteración 47601: Desviación estándar = 8.801830617673929
# Iteración 47701: Desviación estándar = 6.693695209341067
# Iteración 47801: Desviación estándar = 7.3181661333667165
# Iteración 47901: Desviación estándar = 13.900439641328697
# Iteración 48001: Desviación estándar = 6.2915286960589585
# Iteración 48101: Desviación estándar = 13.241349377360804
# Iteración 48201: Desviación estándar = 4.4628092796652945
# Iteración 48301: Desviación estándar = 7.937253933193772
# Iteración 48401: Desviación estándar = 11.991895411299899
# Iteración 48501: Desviación estándar = 8.9566858950296
# Iteración 48601: Desviación estándar = 11.718930554164631
# Iteración 48701: Desviación estándar = 7.852812659593164
# Iteración 48801: Desviación estándar = 13.111699610144623
# Iteración 48901: Desviación estándar = 13.03094607292792
# Iteración 49001: Desviación estándar = 9.961035198322623
# Iteración 49101: Desviación estándar = 10.242883708539635
# Iteración 49201: Desviación estándar = 9.889669132764531
# Iteración 49301: Desviación estándar = 9.843215373488935
# Iteración 49401: Desviación estándar = 11.470977871713176
# Iteración 49501: Desviación estándar = 9.087537253477057
# Iteración 49601: Desviación estándar = 13.696106502701172
# Iteración 49701: Desviación estándar = 7.760297817881877
# Iteración 49801: Desviación estándar = 11.610579466829188
# Iteración 49901: Desviación estándar = 12.827920936595905
# Iteración 50001: Desviación estándar = 11.412712210513327
# Iteración 50101: Desviación estándar = 9.423669962151452
# Iteración 50201: Desviación estándar = 8.881941729649485
# Iteración 50301: Desviación estándar = 10.53169818531972
# Iteración 50401: Desviación estándar = 8.205689083394114
# Iteración 50501: Desviación estándar = 10.279429296739517
# Iteración 50601: Desviación estándar = 3.1622776601683795
# Iteración 50701: Desviación estándar = 8.214147686901072
# Iteración 50801: Desviación estándar = 11.98262631201246
# Iteración 50901: Desviación estándar = 10.593499054713801
# Iteración 51001: Desviación estándar = 7.586537784494029
# Iteración 51101: Desviación estándar = 9.966610925150702
# Iteración 51201: Desviación estándar = 11.126794486983012
# Iteración 51301: Desviación estándar = 13.586144903295171
# Iteración 51401: Desviación estándar = 10.699169230469355
# Iteración 51501: Desviación estándar = 13.889444433333777
# Iteración 51601: Desviación estándar = 9.622023349240706
# Iteración 51701: Desviación estándar = 9.451631252505216
# Iteración 51801: Desviación estándar = 11.04033010778613
# Iteración 51901: Desviación estándar = 10.323920443965719
# Iteración 52001: Desviación estándar = 9.994442900376633
# Iteración 52101: Desviación estándar = 8.234412884690418
# Iteración 52201: Desviación estándar = 9.927515074556952
# Iteración 52301: Desviación estándar = 12.239507978491437
# Iteración 52401: Desviación estándar = 11.967548714010828
# Iteración 52501: Desviación estándar = 12.202003478482085
# Iteración 52601: Desviación estándar = 8.04155872120988
# Iteración 52701: Desviación estándar = 9.533566430716728
# Iteración 52801: Desviación estándar = 7.564537145273478
# Iteración 52901: Desviación estándar = 11.908213785264168
# Iteración 53001: Desviación estándar = 10.094002619817815
# Iteración 53101: Desviación estándar = 7.522189397597839
# Iteración 53201: Desviación estándar = 10.96458946893235
# Iteración 53301: Desviación estándar = 8.99536917900909
# Iteración 53401: Desviación estándar = 10.54619467970425
# Iteración 53501: Desviación estándar = 6.011562932290478
# Iteración 53601: Desviación estándar = 9.13631338244383
# Iteración 53701: Desviación estándar = 8.394773506308685
# Iteración 53801: Desviación estándar = 8.556998435328957
# Iteración 53901: Desviación estándar = 10.16530045465127
# Iteración 54001: Desviación estándar = 11.29527924990495
# Iteración 54101: Desviación estándar = 10.414999866645328
# Iteración 54201: Desviación estándar = 11.021443744910293
# Iteración 54301: Desviación estándar = 10.402991022884823
# Iteración 54401: Desviación estándar = 8.48528137423857
# Iteración 54501: Desviación estándar = 7.958224257542215
# Iteración 54601: Desviación estándar = 12.436505404118419
# Iteración 54701: Desviación estándar = 13.634107557478375
# Iteración 54801: Desviación estándar = 8.933395522171597
# Iteración 54901: Desviación estándar = 8.459051693633013
# Iteración 55001: Desviación estándar = 6.914156170897181
# Iteración 55101: Desviación estándar = 9.91631652042901
# Iteración 55201: Desviación estándar = 10.97977939466707
# Iteración 55301: Desviación estándar = 11.718930554164631
# Iteración 55401: Desviación estándar = 8.717797887081348
# Iteración 55501: Desviación estándar = 10.54619467970425
# Iteración 55601: Desviación estándar = 13.696106502701172
# Iteración 55701: Desviación estándar = 10.225241100118645
# Iteración 55801: Desviación estándar = 10.640593133008245
# Iteración 55901: Desviación estándar = 11.250925887825113
# Iteración 56001: Desviación estándar = 11.682132605916705
# Iteración 56101: Desviación estándar = 10.468205831628136
# Iteración 56201: Desviación estándar = 14.792077459084492
# Iteración 56301: Desviación estándar = 8.013876853447538
# Iteración 56401: Desviación estándar = 11.427306477614632
# Iteración 56501: Desviación estándar = 9.848857801796104
# Iteración 56601: Desviación estándar = 5.527707983925667
# Iteración 56701: Desviación estándar = 11.060440015358038
# Iteración 56801: Desviación estándar = 9.895285072531598
# Iteración 56901: Desviación estándar = 8.629728977333079
# Iteración 57001: Desviación estándar = 10.589565094416715
# Iteración 57101: Desviación estándar = 6.677075208003377
# Iteración 57201: Desviación estándar = 10.350791703482827
# Iteración 57301: Desviación estándar = 8.029459646963936
# Iteración 57401: Desviación estándar = 9.65084912786895
# Iteración 57501: Desviación estándar = 9.927515074556952
# Iteración 57601: Desviación estándar = 3.7601713908928263
# Iteración 57701: Desviación estándar = 12.74972766593685
# Iteración 57801: Desviación estándar = 10.85766498326822
# Iteración 57901: Desviación estándar = 11.489125293076057
# Iteración 58001: Desviación estándar = 14.62209135368657
# Iteración 58101: Desviación estándar = 12.449899597988733
# Iteración 58201: Desviación estándar = 5.94418483337567
# Iteración 58301: Desviación estándar = 13.449494001221343
# Iteración 58401: Desviación estándar = 9.603240193925288
# Iteración 58501: Desviación estándar = 10.945572417902845
# Iteración 58601: Desviación estándar = 7.340905181848414
# Iteración 58701: Desviación estándar = 9.775252199076789
# Iteración 58801: Desviación estándar = 9.172725270544676
# Iteración 58901: Desviación estándar = 12.242911781471305
# Iteración 59001: Desviación estándar = 8.64902049688608
# Iteración 59101: Desviación estándar = 10.242883708539635
# Iteración 59201: Desviación estándar = 9.838981428763628
# Iteración 59301: Desviación estándar = 5.955856128401879
# Iteración 59401: Desviación estándar = 8.64902049688608
# Iteración 59501: Desviación estándar = 8.825468196582484
# Iteración 59601: Desviación estándar = 9.604686356149273
# Iteración 59701: Desviación estándar = 8.008675851155974
# Iteración 59801: Desviación estándar = 11.08552609887726
# Iteración 59901: Desviación estándar = 8.736894948054104
# Iteración 60001: Desviación estándar = 13.005340783266268
# Iteración 60101: Desviación estándar = 12.525529485370624
# Iteración 60201: Desviación estándar = 3.696845502136472
# Iteración 60301: Desviación estándar = 12.711543310445563
# Iteración 60401: Desviación estándar = 11.015141094572204
# Iteración 60501: Desviación estándar = 12.436505404118419
# Iteración 60601: Desviación estándar = 9.285592184789413
# Iteración 60701: Desviación estándar = 9.172725270544674
# Iteración 60801: Desviación estándar = 12.618328820498467
# Iteración 60901: Desviación estándar = 9.746794344808963
# Iteración 61001: Desviación estándar = 14.278966660402597
# Iteración 61101: Desviación estándar = 8.673074554171793
# Iteración 61201: Desviación estándar = 13.208793367383043
# Iteración 61301: Desviación estándar = 5.153208277913436
# Iteración 61401: Desviación estándar = 4.810289896553937
# Iteración 61501: Desviación estándar = 7.987837977547839
# Iteración 61601: Desviación estándar = 9.838981428763628
# Iteración 61701: Desviación estándar = 7.0178344238090995
# Iteración 61801: Desviación estándar = 10.029124255553588
# Iteración 61901: Desviación estándar = 9.826268648655784
# Iteración 62001: Desviación estándar = 7.365459931328117
# Iteración 62101: Desviación estándar = 9.810708435174291
# Iteración 62201: Desviación estándar = 8.615231988880057
# Iteración 62301: Desviación estándar = 8.513061859414755
# Iteración 62401: Desviación estándar = 12.019659821401861
# Iteración 62501: Desviación estándar = 9.759610647971568
# Iteración 62601: Desviación estándar = 9.451631252505216
# Iteración 62701: Desviación estándar = 12.850637684134156
# Iteración 62801: Desviación estándar = 12.880864360230902
# Iteración 62901: Desviación estándar = 7.2264944628929335
# Iteración 63001: Desviación estándar = 10.181682899534175
# Iteración 63101: Desviación estándar = 9.51752769017949
# Iteración 63201: Desviación estándar = 9.556847457887633
# Iteración 63301: Desviación estándar = 12.606215398233788
# Iteración 63401: Desviación estándar = 8.768630958643937
# Iteración 63501: Desviación estándar = 10.589565094416715
# Iteración 63601: Desviación estándar = 9.539392014169456
# Iteración 63701: Desviación estándar = 5.07991688470939
# Iteración 63801: Desviación estándar = 13.203534880225574
# Iteración 63901: Desviación estándar = 9.118052911059953
# Iteración 64001: Desviación estándar = 10.372238588334406
# Iteración 64101: Desviación estándar = 13.631051153728224
# Iteración 64201: Desviación estándar = 10.327955589886445
# Iteración 64301: Desviación estándar = 13.523641850067197
# Iteración 64401: Desviación estándar = 10.934146311237816
# Iteración 64501: Desviación estándar = 9.72396809720988
# Iteración 64601: Desviación estándar = 6.413960468297952
# Iteración 64701: Desviación estándar = 10.462897410479671
# Iteración 64801: Desviación estándar = 10.077477638553981
# Iteración 64901: Desviación estándar = 8.41955396021006
# Iteración 65001: Desviación estándar = 10.402991022884823
# Iteración 65101: Desviación estándar = 10.011104945120804
# Iteración 65201: Desviación estándar = 7.602996485304695
# Iteración 65301: Desviación estándar = 9.843215373488933
# Iteración 65401: Desviación estándar = 11.352924243950934
# Iteración 65501: Desviación estándar = 10.996211468804457
# Iteración 65601: Desviación estándar = 13.601470508735444
# Iteración 65701: Desviación estándar = 11.644025649805712
# Iteración 65801: Desviación estándar = 3.435921354681384
# Iteración 65901: Desviación estándar = 8.082903768654761
# Iteración 66001: Desviación estándar = 11.363929289153857
# Iteración 66101: Desviación estándar = 11.869662543176569
# Iteración 66201: Desviación estándar = 9.285592184789412
# Iteración 66301: Desviación estándar = 7.0
# Iteración 66401: Desviación estándar = 8.749603165604459
# Iteración 66501: Desviación estándar = 12.256517540566822
# Iteración 66601: Desviación estándar = 11.567435132973756
# Iteración 66701: Desviación estándar = 13.573871960498227
# Iteración 66801: Desviación estándar = 13.30413469565007
# Iteración 66901: Desviación estándar = 9.392668535736913
# Iteración 67001: Desviación estándar = 9.65084912786895
# Iteración 67101: Desviación estándar = 13.864422895390282
# Iteración 67201: Desviación estándar = 14.224392195567912
# Iteración 67301: Desviación estándar = 9.073771725877465
# Iteración 67401: Desviación estándar = 13.564659966250536
# Iteración 67501: Desviación estándar = 13.921406378507724
# Iteración 67601: Desviación estándar = 10.873004286866728
# Iteración 67701: Desviación estándar = 9.511688715586851
# Iteración 67801: Desviación estándar = 11.412712210513327
# Iteración 67901: Desviación estándar = 12.879786057574439
# Iteración 68001: Desviación estándar = 11.239810200058244
# Iteración 68101: Desviación estándar = 9.973576200251452
# Iteración 68201: Desviación estándar = 13.107461827354507
# Iteración 68301: Desviación estándar = 12.174654911833116
# Iteración 68401: Desviación estándar = 9.990273047097139
# Iteración 68501: Desviación estándar = 7.49258893099634
# Iteración 68601: Desviación estándar = 10.027739304327548
# Iteración 68701: Desviación estándar = 11.718930554164631
# Iteración 68801: Desviación estándar = 10.750968948580091
# Iteración 68901: Desviación estándar = 12.24744871391589
# Iteración 69001: Desviación estándar = 12.036980056845191
# Iteración 69101: Desviación estándar = 11.085526098877262
# Iteración 69201: Desviación estándar = 11.470977871713176
# Iteración 69301: Desviación estándar = 10.1762250149825
# Iteración 69401: Desviación estándar = 11.343133018115703
# Iteración 69501: Desviación estándar = 10.35615758860399
# Iteración 69601: Desviación estándar = 7.047458170621991
# Iteración 69701: Desviación estándar = 11.234866364235145
# Iteración 69801: Desviación estándar = 11.977989072553965
# Iteración 69901: Desviación estándar = 8.386497083606082
# Iteración 70001: Desviación estándar = 8.112062349091971
# Iteración 70101: Desviación estándar = 8.881941729649485
# Iteración 70201: Desviación estándar = 10.89979612449497
# Iteración 70301: Desviación estándar = 6.5
# Iteración 70401: Desviación estándar = 7.127801593447699
# Iteración 70501: Desviación estándar = 12.508885730640529
# Iteración 70601: Desviación estándar = 13.263358046387298
# Iteración 70701: Desviación estándar = 13.59840676942217
# Iteración 70801: Desviación estándar = 9.154537429906306
# Iteración 70901: Desviación estándar = 9.983319421247959
# Iteración 71001: Desviación estándar = 9.018499505645789
# Iteración 71101: Desviación estándar = 9.39858145324779
# Iteración 71201: Desviación estándar = 10.884494578170463
# Iteración 71301: Desviación estándar = 11.866151674218376
# Iteración 71401: Desviación estándar = 9.012337223063849
# Iteración 71501: Desviación estándar = 9.962429422585638
# Iteración 71601: Desviación estándar = 11.944315244779277
# Iteración 71701: Desviación estándar = 12.203141671990318
# Iteración 71801: Desviación estándar = 5.744562646538029
# Iteración 71901: Desviación estándar = 10.13930744950342
# Iteración 72001: Desviación estándar = 8.615231988880057
# Iteración 72101: Desviación estándar = 11.051646433400268
# Iteración 72201: Desviación estándar = 10.70436048222094
# Iteración 72301: Desviación estándar = 8.153049872423338
# Iteración 72401: Desviación estándar = 11.661903789690601
# Iteración 72501: Desviación estándar = 5.312459150169742
# Iteración 72601: Desviación estándar = 8.301606270274847
# Iteración 72701: Desviación estándar = 9.3571125650788
# Iteración 72801: Desviación estándar = 11.294049564064943
# Iteración 72901: Desviación estándar = 11.953614051360738
# Iteración 73001: Desviación estándar = 11.88369564665059
# Iteración 73101: Desviación estándar = 11.786291472158096
# Iteración 73201: Desviación estándar = 10.652334120849863
# Iteración 73301: Desviación estándar = 10.49470766095411
# Iteración 73401: Desviación estándar = 7.520342781785652
# Iteración 73501: Desviación estándar = 8.952032667997189
# Iteración 73601: Desviación estándar = 13.662601021279464
# Iteración 73701: Desviación estándar = 12.078447287995626
# Iteración 73801: Desviación estándar = 9.464847243000456
# Iteración 73901: Desviación estándar = 10.089873911776873
# Iteración 74001: Desviación estándar = 5.467073155618908
# Iteración 74101: Desviación estándar = 10.420332688227058
# Iteración 74201: Desviación estándar = 13.98411797560202
# Iteración 74301: Desviación estándar = 6.101001739241042
# Iteración 74401: Desviación estándar = 12.143814154631245
# Iteración 74501: Desviación estándar = 13.288466176851765
# Iteración 74601: Desviación estándar = 8.153049872423338
# Iteración 74701: Desviación estándar = 7.8191360704932675
# Iteración 74801: Desviación estándar = 10.062305898749054
# Iteración 74901: Desviación estándar = 9.643650760992955
# Iteración 75001: Desviación estándar = 14.461635069690042
# Iteración 75101: Desviación estándar = 8.65383665716478
# Iteración 75201: Desviación estándar = 11.781576955380615
# Iteración 75301: Desviación estándar = 3.815174380753199
# Iteración 75401: Desviación estándar = 11.567435132973754
# Iteración 75501: Desviación estándar = 10.66796867053684
# Iteración 75601: Desviación estándar = 8.32165848854662
# Iteración 75701: Desviación estándar = 6.2826922749902545
# Iteración 75801: Desviación estándar = 10.482790129010924
# Iteración 75901: Desviación estándar = 10.503967504392486
# Iteración 76001: Desviación estándar = 7.695597587076797
# Iteración 76101: Desviación estándar = 10.253725610181348
# Iteración 76201: Desviación estándar = 10.598742063723098
# Iteración 76301: Desviación estándar = 11.795714852813663
# Iteración 76401: Desviación estándar = 6.046119049072351
# Iteración 76501: Desviación estándar = 12.283683848458853
# Iteración 76601: Desviación estándar = 11.781576955380615
# Iteración 76701: Desviación estándar = 12.884098726725126
# Iteración 76801: Desviación estándar = 9.516068282413466
# Iteración 76901: Desviación estándar = 12.133516482134196
# Iteración 77001: Desviación estándar = 13.901438774457844
# Iteración 77101: Desviación estándar = 9.104333522498443
# Iteración 77201: Desviación estándar = 12.966838045139953
# Iteración 77301: Desviación estándar = 12.575328579758418
# Iteración 77401: Desviación estándar = 9.539392014169456
# Iteración 77501: Desviación estándar = 10.110500592068734
# Iteración 77601: Desviación estándar = 11.01135777277262
# Iteración 77701: Desviación estándar = 14.602130742539675
# Iteración 77801: Desviación estándar = 10.172129679778086
# Iteración 77901: Desviación estándar = 2.362907813126304
# Iteración 78001: Desviación estándar = 12.233832869001711
# Iteración 78101: Desviación estándar = 10.749676997731399
# Iteración 78201: Desviación estándar = 11.412712210513327
# Iteración 78301: Desviación estándar = 12.162099599438687
# Iteración 78401: Desviación estándar = 9.081421817216851
# Iteración 78501: Desviación estándar = 12.737739202856996
# Iteración 78601: Desviación estándar = 10.15983376941878
# Iteración 78701: Desviación estándar = 10.65754818583211
# Iteración 78801: Desviación estándar = 11.62492532831454
# Iteración 78901: Desviación estándar = 9.66091783079296
# Iteración 79001: Desviación estándar = 11.334558757279535
# Iteración 79101: Desviación estándar = 10.89979612449497
# Iteración 79201: Desviación estándar = 11.89887949906769
# Iteración 79301: Desviación estándar = 11.653564070942227
# Iteración 79401: Desviación estándar = 12.019659821401861
# Iteración 79501: Desviación estándar = 14.290634073484012
# Iteración 79601: Desviación estándar = 4.705198071164368
# Iteración 79701: Desviación estándar = 13.291601358251256
# Iteración 79801: Desviación estándar = 6.896053621859067
# Iteración 79901: Desviación estándar = 11.538582620447318
# Iteración 80001: Desviación estándar = 12.401836781523757
# Iteración 80101: Desviación estándar = 11.216307572260826
# Iteración 80201: Desviación estándar = 4.058598553961974
# Iteración 80301: Desviación estándar = 8.914719413544221
# Iteración 80401: Desviación estándar = 13.309353436169951
# Iteración 80501: Desviación estándar = 10.514540197058336
# Iteración 80601: Desviación estándar = 10.826921179274477
# Iteración 80701: Desviación estándar = 7.274384280931732
# Iteración 80801: Desviación estándar = 12.944325225965065
# Iteración 80901: Desviación estándar = 7.357913351548039
# Iteración 81001: Desviación estándar = 9.030811456096044
# Iteración 81101: Desviación estándar = 9.827681991870378
# Iteración 81201: Desviación estándar = 12.86683937707919
# Iteración 81301: Desviación estándar = 9.994442900376633
# Iteración 81401: Desviación estándar = 6.262764742685312
# Iteración 81501: Desviación estándar = 5.467073155618908
# Iteración 81601: Desviación estándar = 9.433981132056603
# Iteración 81701: Desviación estándar = 9.702519718551923
# Iteración 81801: Desviación estándar = 7.564537145273478
# Iteración 81901: Desviación estándar = 14.568802284333465
# Iteración 82001: Desviación estándar = 11.48428878463481
# Iteración 82101: Desviación estándar = 9.007712744581106
# Iteración 82201: Desviación estándar = 9.809292646374775
# Iteración 82301: Desviación estándar = 11.71418892720372
# Iteración 82401: Desviación estándar = 10.515861036231572
# Iteración 82501: Desviación estándar = 8.517954892787092
# Iteración 82601: Desviación estándar = 11.964066569895408
# Iteración 82701: Desviación estándar = 11.524129275375019
# Iteración 82801: Desviación estándar = 9.9958324649159
# Iteración 82901: Desviación estándar = 8.563488385776752
# Iteración 83001: Desviación estándar = 11.396880664852505
# Iteración 83101: Desviación estándar = 12.165525060596439
# Iteración 83201: Desviación estándar = 11.045361017187261
# Iteración 83301: Desviación estándar = 13.461880337539116
# Iteración 83401: Desviación estándar = 9.792287214378922
# Iteración 83501: Desviación estándar = 10.327955589886445
# Iteración 83601: Desviación estándar = 13.901438774457844
# Iteración 83701: Desviación estándar = 5.597618541248888
# Iteración 83801: Desviación estándar = 11.372481406154654
# Iteración 83901: Desviación estándar = 11.599808427536878
# Iteración 84001: Desviación estándar = 13.9134227756269
# Iteración 84101: Desviación estándar = 9.656603957913983
# Iteración 84201: Desviación estándar = 9.759610647971568
# Iteración 84301: Desviación estándar = 7.608474807008885
# Iteración 84401: Desviación estándar = 5.241395064505462
# Iteración 84501: Desviación estándar = 10.21028892833107
# Iteración 84601: Desviación estándar = 10.204846343227754
# Iteración 84701: Desviación estándar = 9.994442900376633
# Iteración 84801: Desviación estándar = 9.099755796479132
# Iteración 84901: Desviación estándar = 13.523641850067197
# Iteración 85001: Desviación estándar = 6.97614984548545
# Iteración 85101: Desviación estándar = 11.781576955380615
# Iteración 85201: Desviación estándar = 11.841546445554409
# Iteración 85301: Desviación estándar = 9.616247824501105
# Se encontró una coincidencia en la iteración 85383
# Conjunto seleccionado: [18, 3, 7, 21, 27, 4]
# Desviación estándar del conjunto seleccionado: 9.140872800534726
# Hubo coincidencia con 6 números: [18, 3, 7, 21, 27, 4]

# %% [markdown]
# ## Simulador con dispercion (Version desactualizada y esta valindando que el random coincida 4 numero)

# %%
# Número de conjuntos a generar
num_conjuntos = 1000

# Variable para almacenar el índice de la coincidencia
indice_coincidencia = None

# Contador de bucles
iteracion = 0

while indice_coincidencia is None:
    iteracion += 1
    # Generar conjuntos basados en las probabilidades
    conjuntos_generados = []
    for _ in range(num_conjuntos):
        # Ordenar las claves por ponderación de mayor a menor
        claves_ordenadas = sorted(probabilidades, key=probabilidades.get, reverse=True)
        
        # Seleccionar 6 elementos sin reemplazo
        conjunto = random.sample(claves_ordenadas, k=6)
        
        # Agregar el conjunto a la lista
        conjuntos_generados.append(conjunto)

    # Calcular la desviación estándar de cada conjunto
    desviaciones_estandar_generadas = [np.std(conjunto) for conjunto in conjuntos_generados]

    # Convertir la lista a un array de NumPy antes de realizar la resta
    desviaciones_estandar_generadas = np.array(desviaciones_estandar_generadas)

    # Encontrar el conjunto con desviación estándar más cercana a la observada
    indice_min_desviacion = np.argmin(np.abs(desviaciones_estandar_generadas - 9.14))
    conjunto_seleccionado = conjuntos_generados[indice_min_desviacion]
    
     # Calcular la desviación estándar del conjunto seleccionado
    desviacion_estandar_seleccionada = np.std(conjunto_seleccionado)
    
    # Imprimir resultados
    print("Conjunto seleccionado:", conjunto_seleccionado)
    print(f"Iteración {iteracion}: Desviación estándar = {desviacion_estandar_seleccionada}")

    # Verificar la coincidencia y almacenar el índice si es igual
    coincidencias = contar_coincidencias(conjunto_seleccionado, last_loto)
    if len(coincidencias) >= 4:
        break

print(f"La coincidencia de 6 datos después de {iteracion} bucles.")
# Out:
# Conjunto seleccionado: [2, 28, 16, 15, 7, 25]
# Iteración 1: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [17, 19, 21, 12, 33, 38]
# Iteración 2: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [29, 14, 17, 11, 1, 4]
# Iteración 3: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [4]
# Conjunto seleccionado: [35, 6, 18, 14, 24, 25]
# Iteración 4: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [29, 34, 19, 31, 7, 20]
# Iteración 5: Desviación estándar = 9.140872800534725
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [33, 36, 38, 15, 16, 27]
# Iteración 6: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [31, 15, 3, 28, 18, 17]
# Iteración 7: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [3, 18]
# Conjunto seleccionado: [9, 19, 1, 29, 12, 22]
# Iteración 8: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [14, 21, 17, 20, 7, 37]
# Iteración 9: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [21, 7]
# Conjunto seleccionado: [16, 36, 22, 14, 30, 10]
# Iteración 10: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [34, 20, 24, 12, 14, 36]
# Iteración 11: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [5, 22, 36, 19, 21, 25]
# Iteración 12: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [24, 21, 35, 16, 28, 6]
# Iteración 13: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [14, 6, 36, 18, 23, 21]
# Iteración 14: Desviación estándar = 9.140872800534725
# Hubo coincidencia con 2 números: [18, 21]
# Conjunto seleccionado: [36, 16, 13, 22, 32, 35]
# Iteración 15: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [12, 37, 35, 34, 28, 19]
# Iteración 16: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [19, 2, 11, 5, 18, 29]
# Iteración 17: Desviación estándar = 9.128709291752768
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [13, 29, 35, 20, 24, 8]
# Iteración 18: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [31, 18, 26, 10, 37, 32]
# Iteración 19: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [14, 19, 21, 8, 4, 32]
# Iteración 20: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [21, 4]
# Conjunto seleccionado: [8, 29, 16, 9, 26, 5]
# Iteración 21: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [17, 7, 16, 36, 26, 25]
# Iteración 22: Desviación estándar = 9.154537429906306
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [37, 19, 9, 21, 28, 14]
# Iteración 23: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [26, 32, 14, 20, 6, 30]
# Iteración 24: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [26, 11, 25, 12, 35, 32]
# Iteración 25: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [22, 12, 15, 14, 37, 30]
# Iteración 26: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [29, 23, 25, 5, 30, 12]
# Iteración 27: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [20, 27, 23, 3, 5, 10]
# Iteración 28: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [27, 3]
# Conjunto seleccionado: [11, 38, 33, 37, 25, 28]
# Iteración 29: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [35, 30, 20, 37, 13, 17]
# Iteración 30: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [19, 25, 5, 27, 3, 15]
# Iteración 31: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [27, 3]
# Conjunto seleccionado: [27, 22, 8, 38, 23, 17]
# Iteración 32: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [30, 16, 6, 20, 2, 14]
# Iteración 33: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [26, 32, 7, 36, 28, 25]
# Iteración 34: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [12, 18, 13, 32, 3, 8]
# Iteración 35: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [18, 3]
# Conjunto seleccionado: [31, 26, 15, 37, 11, 18]
# Iteración 36: Desviación estándar = 9.146948489341495
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [13, 26, 12, 34, 18, 7]
# Iteración 37: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [18, 7]
# Conjunto seleccionado: [23, 34, 6, 24, 20, 32]
# Iteración 38: Desviación estándar = 9.136313382443829
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [28, 4, 16, 20, 31, 27]
# Iteración 39: Desviación estándar = 9.128709291752768
# Hubo coincidencia con 2 números: [4, 27]
# Conjunto seleccionado: [5, 24, 25, 35, 18, 17]
# Iteración 40: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [30, 7, 19, 25, 28, 8]
# Iteración 41: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [26, 7, 20, 13, 15, 35]
# Iteración 42: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [19, 23, 30, 11, 1, 16]
# Iteración 43: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [26, 20, 24, 10, 6, 2]
# Iteración 44: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [14, 16, 13, 36, 28, 11]
# Iteración 45: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [31, 32, 9, 11, 20, 14]
# Iteración 46: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [36, 24, 21, 8, 22, 11]
# Iteración 47: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [30, 25, 18, 24, 26, 2]
# Iteración 48: Desviación estándar = 9.136313382443829
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [18, 7, 29, 2, 8, 6]
# Iteración 49: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [18, 7]
# Conjunto seleccionado: [7, 34, 19, 17, 27, 11]
# Iteración 50: Desviación estándar = 9.136313382443829
# Hubo coincidencia con 2 números: [7, 27]
# Conjunto seleccionado: [15, 10, 35, 17, 31, 28]
# Iteración 51: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [17, 33, 32, 10, 35, 25]
# Iteración 52: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [8, 36, 30, 28, 17, 23]
# Iteración 53: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [34, 33, 10, 32, 19, 18]
# Iteración 54: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [24, 33, 31, 26, 5, 21]
# Iteración 55: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [30, 11, 25, 14, 16, 2]
# Iteración 56: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [30, 18, 15, 22, 32, 5]
# Iteración 57: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [36, 23, 11, 9, 26, 19]
# Iteración 58: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [7, 34, 20, 8, 12, 16]
# Iteración 59: Desviación estándar = 9.13631338244383
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [8, 22, 16, 28, 24, 2]
# Iteración 60: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [24, 35, 7, 21, 31, 30]
# Iteración 61: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [7, 21]
# Conjunto seleccionado: [28, 18, 8, 21, 9, 33]
# Iteración 62: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 2 números: [18, 21]
# Conjunto seleccionado: [23, 13, 18, 15, 7, 36]
# Iteración 63: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [18, 7]
# Conjunto seleccionado: [30, 16, 2, 27, 17, 14]
# Iteración 64: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [37, 10, 18, 30, 22, 32]
# Iteración 65: Desviación estándar = 9.13631338244383
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [19, 38, 25, 8, 26, 18]
# Iteración 66: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [19, 5, 29, 15, 21, 33]
# Iteración 67: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [21, 5, 14, 35, 17, 23]
# Iteración 68: Desviación estándar = 9.13631338244383
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [17, 2, 29, 10, 23, 24]
# Iteración 69: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [27, 25, 14, 26, 12, 2]
# Iteración 70: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [32, 14, 11, 29, 7, 19]
# Iteración 71: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [31, 22, 8, 25, 37, 30]
# Iteración 72: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [1, 5, 27, 10, 16, 22]
# Iteración 73: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [8, 29, 20, 27, 38, 25]
# Iteración 74: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [28, 30, 10, 14, 5, 21]
# Iteración 75: Desviación estándar = 9.146948489341495
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [10, 26, 21, 37, 13, 28]
# Iteración 76: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [16, 26, 27, 37, 8, 20]
# Iteración 77: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [12, 4, 29, 27, 18, 9]
# Iteración 78: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 3 números: [4, 27, 18]
# Conjunto seleccionado: [7, 22, 1, 28, 9, 13]
# Iteración 79: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [38, 16, 32, 24, 11, 21]
# Iteración 80: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [5, 17, 33, 11, 18, 8]
# Iteración 81: Desviación estándar = 9.140872800534725
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [20, 30, 16, 5, 9, 28]
# Iteración 82: Desviación estándar = 9.146948489341495
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [18, 32, 26, 22, 9, 37]
# Iteración 83: Desviación estándar = 9.146948489341495
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [15, 26, 19, 4, 31, 10]
# Iteración 84: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [4]
# Conjunto seleccionado: [10, 33, 32, 18, 30, 35]
# Iteración 85: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [18]
# Conjunto seleccionado: [19, 32, 37, 30, 16, 12]
# Iteración 86: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [21, 4, 17, 31, 29, 14]
# Iteración 87: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 2 números: [21, 4]
# Conjunto seleccionado: [15, 16, 28, 38, 31, 37]
# Iteración 88: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [24, 10, 32, 30, 20, 8]
# Iteración 89: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [13, 36, 37, 19, 35, 29]
# Iteración 90: Desviación estándar = 9.13631338244383
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [15, 31, 17, 6, 8, 27]
# Iteración 91: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [16, 15, 24, 28, 26, 1]
# Iteración 92: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [20, 24, 18, 4, 34, 26]
# Iteración 93: Desviación estándar = 9.146948489341495
# Hubo coincidencia con 2 números: [18, 4]
# Conjunto seleccionado: [9, 10, 4, 31, 8, 20]
# Iteración 94: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [4]
# Conjunto seleccionado: [27, 12, 30, 21, 5, 28]
# Iteración 95: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 2 números: [27, 21]
# Conjunto seleccionado: [20, 9, 34, 23, 12, 8]
# Iteración 96: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [7, 4, 16, 12, 31, 6]
# Iteración 97: Desviación estándar = 9.122621455602674
# Hubo coincidencia con 2 números: [7, 4]
# Conjunto seleccionado: [17, 31, 28, 21, 9, 6]
# Iteración 98: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [21]
# Conjunto seleccionado: [17, 30, 27, 37, 20, 9]
# Iteración 99: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [6, 11, 31, 8, 19, 5]
# Iteración 100: Desviación estándar = 9.140872800534725
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [4, 11, 13, 30, 25, 9]
# Iteración 101: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [4]
# Conjunto seleccionado: [11, 15, 2, 9, 31, 20]
# Iteración 102: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [25, 9, 34, 32, 37, 27]
# Iteración 103: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [9, 35, 32, 27, 22, 15]
# Iteración 104: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [12, 2, 14, 6, 27, 25]
# Iteración 105: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [16, 14, 20, 30, 2, 6]
# Iteración 106: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 0 números: []
# Conjunto seleccionado: [13, 14, 4, 7, 29, 1]
# Iteración 107: Desviación estándar = 9.140872800534725
# Hubo coincidencia con 2 números: [4, 7]
# Conjunto seleccionado: [24, 2, 13, 27, 6, 9]
# Iteración 108: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [19, 11, 6, 25, 4, 28]
# Iteración 109: Desviación estándar = 9.142392101268317
# Hubo coincidencia con 1 números: [4]
# Conjunto seleccionado: [14, 17, 15, 31, 7, 32]
# Iteración 110: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [7]
# Conjunto seleccionado: [23, 37, 19, 10, 12, 27]
# Iteración 111: Desviación estándar = 9.140872800534726
# Hubo coincidencia con 1 números: [27]
# Conjunto seleccionado: [27, 8, 21, 3, 19, 4]
# Iteración 112: Desviación estándar = 9.122621455602673
# Hubo coincidencia con 4 números: [27, 21, 3, 4]
# La coincidencia de 6 datos después de 112 bucles.
